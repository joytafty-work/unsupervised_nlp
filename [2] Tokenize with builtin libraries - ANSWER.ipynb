# %% [markdown]
# # ANSWER Exercise: Tokenize with NLTK tokenizer or sklearn tokenizer

# %% [raw]
# Exercise 2.1 Load text data in '1.ted' from from './ted_mini/sci_positive/' directory.
# Clean up text then tokenize with NLTK tokenizer or sklearn tokenizer
#
# From last lecture: CountVectorizer from sklearn
# from sklearn.feature_extraction.text import CountVectorizer
#
# Other libraries: Gensim
# from gensim import corpora

# %%
# Hint: You can use readline() or readlines() to read text file
# Then use sci-kit learn CountVectorizer (last lecture) to tokenize/vectorize
# from sklearn.feature_extraction.text import CountVectorizer
#
# ## Feel free to uncomment the code below to turn raw data into bag of words 
# -------------------------------------------
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.stem import PorterStemmer
import nltk
import re, string
from itertools import chain 
## Read in raw data
dPath = './ted_mini/art_positive/'
with open('%s/%s' % (dPath, '5.ted'), 'r') as f: 
    dat = f.readlines()

# Clean/Tokenize/Stemmize&Lemmatize
dat_list = list(chain(*map(lambda x: x.replace("_en", "").strip("\n").lower().split(' '), dat)))
dat_list = filter(lambda y: (len(y) > 1) and (not y.isdigit()),
                  map(lambda x: re.sub('[{}]'.format(re.escape(string.punctuation)), '', x), dat_list))
lmtzr = WordNetLemmatizer()
pst = PorterStemmer()
stop_words = nltk.corpus.stopwords.words('english')
# dat_list = filter(lambda y: y not in stop_words, map(lambda x: pst.stem(lmtzr.lemmatize(x)), dat_list))
dat_list = filter(lambda y: y not in stop_words, map(lambda x: lmtzr.lemmatize(x), dat_list))

from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd
cv = CountVectorizer()
vec = cv.fit(dat)
df = pd.DataFrame(
    vec.vocabulary_.items())
        .rename(columns={0:'word', 1:'count'})
        .sort('count', ascending=0)
        .reset_index(drop=True)
)
# Out:
# {u'able': 0,
#  u'accept': 1,
#  u'accepted': 2,
#  u'actually': 3,
#  u'add': 4,
#  u'admit': 5,
#  u'aesthetic': 6,
#  u'agenda': 7,
#  u'ahead': 8,
#  u'air': 9,
#  u'alive': 10,
#  u'also': 11,
#  u'america': 12,
#  u'analogy': 13,
#  u'anger': 14,
#  u'anybody': 15,
#  u'anything': 16,
#  u'anyway': 17,
#  u'apart': 18,
#  u'apartment': 19,
#  u'applicable': 20,
#  u'approach': 21,
#  u'around': 22,
#  u'art': 23,
#  u'artist': 24,
#  u'artistic': 25,
#  u'ask': 26,
#  u'asked': 27,
#  u'asking': 28,
#  u'automobile': 29,
#  u'avatar': 30,
#  u'baby': 31,
#  u'back': 32,
#  u'background': 33,
#  u'baffled': 34,
#  u'ballistic': 35,
#  u'based': 36,
#  u'basically': 37,
#  u'bathroom': 38,
#  u'bathtub': 39,
#  u'beauty': 40,
#  u'becoming': 41,
#  u'bed': 42,
#  u'behind': 43,
#  u'belief': 44,
#  u'believe': 45,
#  u'better': 46,
#  u'beyond': 47,
#  u'big': 48,
#  u'bit': 49,
#  u'blue': 50,
#  u'bmw': 51,
#  u'bmws': 52,
#  u'board': 53,
#  u'bond': 54,
#  u'book': 55,
#  u'bos': 56,
#  u'bound': 57,
#  u'brilliance': 58,
#  u'bring': 59,
#  u'brings': 60,
#  u'broke': 61,
#  u'brute': 62,
#  u'budget': 63,
#  u'built': 64,
#  u'bullshit': 65,
#  u'business': 66,
#  u'butt': 67,
#  u'ca': 68,
#  u'called': 69,
#  u'came': 70,
#  u'cannot': 71,
#  u'canyon': 72,
#  u'capital': 73,
#  u'car': 74,
#  u'carl': 75,
#  u'catch': 76,
#  u'catherine': 77,
#  u'cell': 78,
#  u'center': 79,
#  u'certain': 80,
#  u'certainly': 81,
#  u'chance': 82,
#  u'changed': 83,
#  u'cheaper': 84,
#  u'chevy': 85,
#  u'chris': 86,
#  u'clay': 87,
#  u'clever': 88,
#  u'closer': 89,
#  u'clothes': 90,
#  u'co': 91,
#  u'coffee': 92,
#  u'collusion': 93,
#  u'come': 94,
#  u'coming': 95,
#  u'commitment': 96,
#  u'company': 97,
#  u'compare': 98,
#  u'competitive': 99,
#  u'complete': 100,
#  u'completely': 101,
#  u'computer': 102,
#  u'concept': 103,
#  u'conclusion': 104,
#  u'condition': 105,
#  u'confronting': 106,
#  u'congestion': 107,
#  u'connected': 108,
#  u'consumer': 109,
#  u'contact': 110,
#  u'control': 111,
#  u'cool': 112,
#  u'could': 113,
#  u'counting': 114,
#  u'coupe': 115,
#  u'course': 116,
#  u'craft': 117,
#  u'craftsmanship': 118,
#  u'create': 119,
#  u'created': 120,
#  u'creating': 121,
#  u'creation': 122,
#  u'creative': 123,
#  u'creativity': 124,
#  u'crossover': 125,
#  u'cup': 126,
#  u'customer': 127,
#  u'cut': 128,
#  u'dance': 129,
#  u'day': 130,
#  u'dazzled': 131,
#  u'deal': 132,
#  u'dealing': 133,
#  u'death': 134,
#  u'decided': 135,
#  u'deep': 136,
#  u'deliverable': 137,
#  u'describes': 138,
#  u'design': 139,
#  u'designer': 140,
#  u'dialog': 141,
#  u'dictate': 142,
#  u'different': 143,
#  u'difficult': 144,
#  u'dimension': 145,
#  u'director': 146,
#  u'disappeared': 147,
#  u'discover': 148,
#  u'discovered': 149,
#  u'discovering': 150,
#  u'discovery': 151,
#  u'discus': 152,
#  u'diverge': 153,
#  u'divergence': 154,
#  u'diverse': 155,
#  u'doe': 156,
#  u'done': 157,
#  u'downstairs': 158,
#  u'dozen': 159,
#  u'dr': 160,
#  u'drawing': 161,
#  u'either': 162,
#  u'elevator': 163,
#  u'elizabeth': 164,
#  u'else': 165,
#  u'emotion': 166,
#  u'emotional': 167,
#  u'end': 168,
#  u'engineer': 169,
#  u'entire': 170,
#  u'even': 171,
#  u'ever': 172,
#  u'every': 173,
#  u'everything': 174,
#  u'ex': 175,
#  u'exist': 176,
#  u'expansion': 177,
#  u'expected': 178,
#  u'expecting': 179,
#  u'experience': 180,
#  u'express': 181,
#  u'fact': 182,
#  u'fair': 183,
#  u'faith': 184,
#  u'fall': 185,
#  u'family': 186,
#  u'fantastic': 187,
#  u'far': 188,
#  u'fascinating': 189,
#  u'favorite': 190,
#  u'fax': 191,
#  u'feel': 192,
#  u'felt': 193,
#  u'female': 194,
#  u'figure': 195,
#  u'figured': 196,
#  u'find': 197,
#  u'finding': 198,
#  u'first': 199,
#  u'five': 200,
#  u'flew': 201,
#  u'fly': 202,
#  u'focus': 203,
#  u'forged': 204,
#  u'form': 205,
#  u'found': 206,
#  u'four': 207,
#  u'free': 208,
#  u'frustration': 209,
#  u'fucking': 210,
#  u'fuel': 211,
#  u'full': 212,
#  u'fun': 213,
#  u'function': 214,
#  u'functionally': 215,
#  u'furious': 216,
#  u'future': 217,
#  u'gave': 218,
#  u'gene': 219,
#  u'generation': 220,
#  u'germany': 221,
#  u'get': 222,
#  u'getting': 223,
#  u'give': 224,
#  u'go': 225,
#  u'going': 226,
#  u'good': 227,
#  u'goschel': 228,
#  u'got': 229,
#  u'gotten': 230,
#  u'grand': 231,
#  u'great': 232,
#  u'group': 233,
#  u'guess': 234,
#  u'guilty': 235,
#  u'guy': 236,
#  u'ha': 237,
#  u'half': 238,
#  u'hand': 239,
#  u'handle': 240,
#  u'happen': 241,
#  u'happened': 242,
#  u'haul': 243,
#  u'head': 244,
#  u'heard': 245,
#  u'heart': 246,
#  u'hell': 247,
#  u'help': 248,
#  u'henry': 249,
#  u'hip': 250,
#  u'holder': 251,
#  u'holiday': 252,
#  u'honest': 253,
#  u'honestly': 254,
#  u'hook': 255,
#  u'hope': 256,
#  u'hopefully': 257,
#  u'hoping': 258,
#  u'hour': 259,
#  u'house': 260,
#  u'however': 261,
#  u'hydrogen': 262,
#  u'ibm': 263,
#  u'idea': 264,
#  u'iful': 265,
#  u'imagine': 266,
#  u'important': 267,
#  u'incredible': 268,
#  u'incredibly': 269,
#  u'independent': 270,
#  u'indication': 271,
#  u'infected': 272,
#  u'infectiousness': 273,
#  u'inside': 274,
#  u'instead': 275,
#  u'intense': 276,
#  u'intensive': 277,
#  u'interchangeable': 278,
#  u'interest': 279,
#  u'interested': 280,
#  u'interesting': 281,
#  u'intimacy': 282,
#  u'irrationalisms': 283,
#  u'job': 284,
#  u'joseph': 285,
#  u'kept': 286,
#  u'kill': 287,
#  u'killing': 288,
#  u'kind': 289,
#  u'know': 290,
#  u'la': 291,
#  u'lady': 292,
#  u'lamp': 293,
#  u'last': 294,
#  u'le': 295,
#  u'lead': 296,
#  u'leap': 297,
#  u'learn': 298,
#  u'learning': 299,
#  u'least': 300,
#  u'left': 301,
#  u'lesson': 302,
#  u'letting': 303,
#  u'level': 304,
#  u'life': 305,
#  u'like': 306,
#  u'literally': 307,
#  u'little': 308,
#  u'live': 309,
#  u'lived': 310,
#  u'living': 311,
#  u'll': 312,
#  u'locked': 313,
#  u'long': 314,
#  u'look': 315,
#  u'looked': 316,
#  u'lot': 317,
#  u'love': 318,
#  u'low': 319,
#  u'lunch': 320,
#  u'machine': 321,
#  u'made': 322,
#  u'magnusson': 323,
#  u'make': 324,
#  u'making': 325,
#  u'malibu': 326,
#  u'management': 327,
#  u'manly': 328,
#  u'many': 329,
#  u'map': 330,
#  u'marketing': 331,
#  u'married': 332,
#  u'master': 333,
#  u'may': 334,
#  u'maybe': 335,
#  u'mean': 336,
#  u'meaning': 337,
#  u'meaningful': 338,
#  u'meant': 339,
#  u'meeting': 340,
#  u'men': 341,
#  u'mental': 342,
#  u'mentor': 343,
#  u'merely': 344,
#  u'method': 345,
#  u'michelangelo': 346,
#  u'middle': 347,
#  u'model': 348,
#  u'modern': 349,
#  u'moment': 350,
#  u'money': 351,
#  u'month': 352,
#  u'monumental': 353,
#  u'moore': 354,
#  u'motorcycle': 355,
#  u'moving': 356,
#  u'much': 357,
#  u'multiply': 358,
#  u'munich': 359,
#  u'museum': 360,
#  u'name': 361,
#  u'narrow': 362,
#  u'need': 363,
#  u'neighbor': 364,
#  u'ness': 365,
#  u'never': 366,
#  u'new': 367,
#  u'newtonian': 368,
#  u'next': 369,
#  u'niagara': 370,
#  u'nice': 371,
#  u'note': 372,
#  u'nothing': 373,
#  u'nt': 374,
#  u'number': 375,
#  u'nut': 376,
#  u'obligation': 377,
#  u'obvious': 378,
#  u'ok': 379,
#  u'one': 380,
#  u'opinion': 381,
#  u'order': 382,
#  u'organization': 383,
#  u'original': 384,
#  u'outside': 385,
#  u'page': 386,
#  u'pain': 387,
#  u'painting': 388,
#  u'paradox': 389,
#  u'part': 390,
#  u'party': 391,
#  u'pas': 392,
#  u'past': 393,
#  u'people': 394,
#  u'perhaps': 395,
#  u'permit': 396,
#  u'phenomenon': 397,
#  u'philippe': 398,
#  u'phone': 399,
#  u'physical': 400,
#  u'picture': 401,
#  u'pin': 402,
#  u'place': 403,
#  u'plane': 404,
#  u'platonic': 405,
#  u'point': 406,
#  u'pole': 407,
#  u'pollute': 408,
#  u'pollution': 409,
#  u'pop': 410,
#  u'postcard': 411,
#  u'premise': 412,
#  u'present': 413,
#  u'presentation': 414,
#  u'pressure': 415,
#  u'pretty': 416,
#  u'priest': 417,
#  u'prince': 418,
#  u'probably': 419,
#  u'problem': 420,
#  u'process': 421,
#  u'produce': 422,
#  u'product': 423,
#  u'project': 424,
#  u'proposal': 425,
#  u'puppy': 426,
#  u'purpose': 427,
#  u'push': 428,
#  u'put': 429,
#  u'pygmalion': 430,
#  u'qualifying': 431,
#  u'quantifiable': 432,
#  u'quantification': 433,
#  u'quantum': 434,
#  u'question': 435,
#  u'quickly': 436,
#  u'quiet': 437,
#  u'quite': 438,
#  u'quote': 439,
#  u'rage': 440,
#  u'rain': 441,
#  u're': 442,
#  u'read': 443,
#  u'real': 444,
#  u'realized': 445,
#  u'really': 446,
#  u'recalled': 447,
#  u'reflect': 448,
#  u'regard': 449,
#  u'relationship': 450,
#  u'remember': 451,
#  u'removed': 452,
#  u'rendition': 453,
#  u'rent': 454,
#  u'reproduce': 455,
#  u'reproduction': 456,
#  u'research': 457,
#  u'resolved': 458,
#  u'result': 459,
#  u'right': 460,
#  u'road': 461,
#  u'rock': 462,
#  u'room': 463,
#  u'rule': 464,
#  u'said': 465,
#  u'sat': 466,
#  u'say': 467,
#  u'saying': 468,
#  u'screamed': 469,
#  u'screwing': 470,
#  u'sculpted': 471,
#  u'sculpting': 472,
#  u'sculpture': 473,
#  u'searching': 474,
#  u'second': 475,
#  u'see': 476,
#  u'seen': 477,
#  u'self': 478,
#  u'selfish': 479,
#  u'sense': 480,
#  u'sensuality': 481,
#  u'sent': 482,
#  u'separately': 483,
#  u'serious': 484,
#  u'seriously': 485,
#  u'sermon': 486,
#  u'set': 487,
#  u'seven': 488,
#  u'sex': 489,
#  u'sexy': 490,
#  u'shared': 491,
#  u'show': 492,
#  u'showed': 493,
#  u'showing': 494,
#  u'shown': 495,
#  u'sick': 496,
#  u'side': 497,
#  u'since': 498,
#  u'six': 499,
#  u'sketch': 500,
#  u'snow': 501,
#  u'society': 502,
#  u'solidarity': 503,
#  u'solution': 504,
#  u'solve': 505,
#  u'solving': 506,
#  u'somebody': 507,
#  u'somehow': 508,
#  u'someone': 509,
#  u'something': 510,
#  u'sometimes': 511,
#  u'song': 512,
#  u'soon': 513,
#  u'sort': 514,
#  u'soul': 515,
#  u'speech': 516,
#  u'speed': 517,
#  u'spending': 518,
#  u'spent': 519,
#  u'split': 520,
#  u'staff': 521,
#  u'stand': 522,
#  u'starck': 523,
#  u'start': 524,
#  u'started': 525,
#  u'station': 526,
#  u'stay': 527,
#  u'stayed': 528,
#  u'steal': 529,
#  u'still': 530,
#  u'stole': 531,
#  u'stood': 532,
#  u'story': 533,
#  u'stress': 534,
#  u'stressed': 535,
#  u'string': 536,
#  u'strong': 537,
#  u'studio': 538,
#  u'stuff': 539,
#  u'substitution': 540,
#  u'successive': 541,
#  u'successor': 542,
#  u'suit': 543,
#  u'super': 544,
#  u'supposed': 545,
#  u'sure': 546,
#  u'surface': 547,
#  u'surroundings': 548,
#  u'survive': 549,
#  u'suv': 550,
#  u'synonymous': 551,
#  u'table': 552,
#  u'take': 553,
#  u'taken': 554,
#  u'talk': 555,
#  u'talking': 556,
#  u'taylor': 557,
#  u'team': 558,
#  u'tear': 559,
#  u'tell': 560,
#  u'telling': 561,
#  u'temperament': 562,
#  u'tend': 563,
#  u'tension': 564,
#  u'terminology': 565,
#  u'thanks': 566,
#  u'thing': 567,
#  u'think': 568,
#  u'thinking': 569,
#  u'though': 570,
#  u'thought': 571,
#  u'three': 572,
#  u'tiburon': 573,
#  u'time': 574,
#  u'timetable': 575,
#  u'tirade': 576,
#  u'today': 577,
#  u'together': 578,
#  u'told': 579,
#  u'took': 580,
#  u'toothbrush': 581,
#  u'totem': 582,
#  u'touch': 583,
#  u'towards': 584,
#  u'triggered': 585,
#  u'true': 586,
#  u'truism': 587,
#  u'truly': 588,
#  u'trust': 589,
#  u'truth': 590,
#  u'try': 591,
#  u'trying': 592,
#  u'turn': 593,
#  u'turned': 594,
#  u'two': 595,
#  u'type': 596,
#  u'understand': 597,
#  u'use': 598,
#  u'used': 599,
#  u'vanity': 600,
#  u've': 601,
#  u'vega': 602,
#  u'vision': 603,
#  u'vocabulary': 604,
#  u'wa': 605,
#  u'wagon': 606,
#  u'waiting': 607,
#  u'waldo': 608,
#  u'walk': 609,
#  u'want': 610,
#  u'wanted': 611,
#  u'war': 612,
#  u'wash': 613,
#  u'way': 614,
#  u'week': 615,
#  u'well': 616,
#  u'went': 617,
#  u'whatever': 618,
#  u'wheel': 619,
#  u'whole': 620,
#  u'wife': 621,
#  u'within': 622,
#  u'without': 623,
#  u'woman': 624,
#  u'wonderful': 625,
#  u'word': 626,
#  u'work': 627,
#  u'worked': 628,
#  u'working': 629,
#  u'worry': 630,
#  u'worthwhile': 631,
#  u'would': 632,
#  u'wow': 633,
#  u'wrapped': 634,
#  u'wrist': 635,
#  u'year': 636,
#  u'yelled': 637,
#  u'york': 638,
#  u'young': 639}

# %%
import pandas as pd
pd.DataFrame(vec.vocabulary_.items()).rename(columns={0:'word', 1:'count'}).sort('count', ascending=0).reset_index(drop=True)
# Out:
#            word  count
# 0         young    639
# 1          york    638
# 2        yelled    637
# 3          year    636
# 4         wrist    635
# 5       wrapped    634
# 6           wow    633
# 7         would    632
# 8    worthwhile    631
# 9         worry    630
# 10      working    629
# 11       worked    628
# 12         work    627
# 13         word    626
# 14    wonderful    625
# 15        woman    624
# 16      without    623
# 17       within    622
# 18         wife    621
# 19        whole    620
# 20        wheel    619
# 21     whatever    618
# 22         went    617
# 23         well    616
# 24         week    615
# 25          way    614
# 26         wash    613
# 27          war    612
# 28       wanted    611
# 29         want    610
# ..          ...    ...
# 610  automobile     29
# 611      asking     28
# 612       asked     27
# 613         ask     26
# 614    artistic     25
# 615      artist     24
# 616         art     23
# 617      around     22
# 618    approach     21
# 619  applicable     20
# 620   apartment     19
# 621       apart     18
# 622      anyway     17
# 623    anything     16
# 624     anybody     15
# 625       anger     14
# 626     analogy     13
# 627     america     12
# 628        also     11
# 629       alive     10
# 630         air      9
# 631       ahead      8
# 632      agenda      7
# 633   aesthetic      6
# 634       admit      5
# 635         add      4
# 636    actually      3
# 637    accepted      2
# 638      accept      1
# 639        able      0
#
# [640 rows x 2 columns]
